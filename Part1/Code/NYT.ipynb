# %%
# Importing packages

import pandas as pd
import json
import numpy as np
import requests
import re

# nltk for text processing 
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.tokenize import word_tokenize

from bs4 import BeautifulSoup
from bs4 import BeautifulSoup
import urllib.request

# Wordnet Lemmatizer
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
np.random.seed(7)
import re
import time

# Spacy for text processing 
import spacy 

# Punctuation removal
import string
punctuations = string.punctuation

# Selecting the sub-topcis on which to fetch the data
small_top = []
small_top.append("Sports")
#small_top.append("soccer")
#small_top.append("baseball")
#small_top.append("basketball")
#small_top.append("football")
#small_top.append("golf")

# Iterating for each subtopic
for wrdss in small_top:
    urlss = []       
    for cnt in range(1,2): 
        time.sleep(11)
        state_link = "https://api.nytimes.com/svc/search/v2/articlesearch.json?q="+str(wrdss)+"&begin_date=20190101&page="+str(cnt)+"&api-key=6dqBKUiy4CGD7qvuIp6KoGfj4KUDzGvR"
        intermediate = requests.get(state_link)
        json_op = json.loads(intermediate.text)
        for data_points in json_op["response"]["docs"]:
            urlss.append(data_points["web_url"])
            
            
    content = [] 
    # Content has the data from the NYT articles
    for url in urlss:
            tmp = urllib.request.urlopen(url).read()
            B_output = BeautifulSoup(tmp, "lxml")
            parameters = B_output.findAll('p')
            content_string = ""
            for sentences in parameters:
                content_string = content_string + sentences.getText()
                
            # Preprocess text to remove junk words/pronouns/punctuations/perform stemming    
            lemmatizer = WordNetLemmatizer()      
            content_string = re.sub(r"http\S+", "", content_string) 
            content_string = content_string.replace('\d+', '')
            content_string = re.sub(r'\d+', '', content_string)
            content_string = content_string.strip().lower()              
            words = word_tokenize(content_string)
            words = [tok.lower().strip() if tok != "-PRON-" else tok.lower_ for tok in words]
            content_string = ' '.join([lemmatizer.lemmatize(word) for word in words]) 
            content.append(content_string)

# NYT Articles data
print(content)

# NYT Articles urls
print(urlss)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ["advertisementsupported byby the associated presstiger wood ' win at the master is still a hot topic . podcastone sport now host jim litke and tim dahlberg look back at the memorable moment that transcended the sport world . litke and dahlberg also discus what wood may do next for his career and the sport with ap golf writer doug ferguson , who wa honored last week for receiving the pga lifetime achievement award in journalism.guest host larry lage catch up with mike tirico of nbc sport after he filled in a an announcer at the master for westwood one radio . jemele hill , a staff writer for the atlantic and host of `` jemele hill is unbothered , '' share her thought on wood ' comeback and the essay kyle korver of the utah jazz recently wrote about white privilege for the player ' tribune.espn analyst chauncey billups wrap up the weekly podcast , talking about his admiration for wood . the nba champion also break down the nba playoff , recall being part of the infamous brawl involving the detroit piston , indiana pacer and fan nearly year ago and say he want to be an nba general manager.advertisement", 'paul manafort ’ s trail of scandalsmy dead dad ’ s porno tapesten meter towerbetween sound and silencecoal miner to trump : “ coal mining isn ’ t coming back ”